# %% [markdown]
# # Data preparation for Restaurant AI

# %% [markdown]
# This data is provided by kaggle. Zomato 2022 Kolkata data

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Function to extract location:

# %%
def extract_parts_of_loc(address, index):
    """
    Extracts parts from location

    Args:
        address (string): Takes in the whole string address
        index (int): The index to determine which part of the address to extract.

    Returns:
        str: The extracted location part of the address.

    Example: 
        address = "1, Middleton Row, Near Loreto House, Park Street Area, Kolkata"
        
        overall_location = extract_location(address,-1)
        -> Kolkata

        overall_location = extract_location(address,-2)
        ->Park Street Area
    """
    # Split the address into parts
    address_parts = address.split(', ')

    #print(address_parts)

    if index==-1:
        loc = "".join(address_parts[index:])
    else:
        # Identify the relevant part (e.g., the last two elements)
        loc = "".join(address_parts[index:index+1])
    
    return loc

# %%
def extract_location(address):
    # Split the address into parts
    address_parts = address.split(', ')
    
    # Identify the relevant part (e.g., the last two elements)
    relevant_part = ', '.join(address_parts[-2:])
    
    return relevant_part

# Example usage
address = "1, Middleton Row, Near Loreto House, Park Street Area, Kolkata"
overall_location = extract_location(address)
print(overall_location)
# Out:
# Park Street Area, Kolkata

# %% [markdown]
# ## Import table:

# %%
import pandas as pd

# Specify the path to your CSV file
file_path = 'Zkolkata.csv'

# Load the CSV file into a pandas DataFrame
df = pd.read_csv(file_path)

# %% [markdown]
# ### Visualize
# Visualize the top 5 entries

# %%
df.head()
# Out:
#                  name    voteCount rating  \
# 0           Peter Cat  12404 votes    4.2
# 1  Naturals Ice Cream   2498 votes    4.9
# 2          Carpe Diem   4083 votes    4.4
# 3     Barbeque Nation   5455 votes    4.6
# 4              Flurys   4709 votes    4.2
#
#                                              address  \
# 0        18A, Park Street, Park Street Area, Kolkata
# 1  77/1/A, Ground Floor, Near West Bengal Board, ...
# 2                     18M, Park Street Area, Kolkata
# 3  1st Floor, 24, Park Center Building, Park Stre...
# 4       15, Apeejay House, Park Street Area, Kolkata
#
#                                cusine    cost  \
# 0           North Indian, Continental  ₹1,000
# 1           North Indian, Continental    ₹200
# 2                           Ice Cream  ₹1,000
# 3                           Ice Cream  ₹1,800
# 4  Chinese, North Indian, Continental    ₹400
#
#                                             timing
# 0                         11am – 11:20pm (Mon-Sun)
# 1                      11am – 12midnight (Mon-Sun)
# 2  12noon – 12midnight (Mon, Tue, Wed, Thu, Fri...
# 3      12noon – 3:30pm, 6:30pm – 10:45pm (Mon-Sun)
# 4                          7:30am – 11pm (Mon-Sun)

# %%
# Example: Get unique values of a specific column
unique_values_column = df['name'].unique()
unique_values_column[5:20]
# Out:
# array(['KFC', 'Tung Fong', 'Arsalan', 'Kusum Rolls', "Kareem's",
#        'WOW! China', 'Golden Spoon', 'BarBQ', 'The Kebab Factory',
#        'Patisserie By Franziska', 'The Sixth Sense', 'Food King',
#        'Burgrill', 'Zainab Biryani', 'The Crepe Cafe'], dtype=object)

# %%
# Apply extract location in top 100 rows
address = df['address']
df['Location'] = address[0:100].apply(extract_location)

# %%
# Example: Get unique values of a specific column
unique_values_column = df['name'].unique()
unique_values_column[5:20]
# Out:
# array(['KFC', 'Tung Fong', 'Arsalan', 'Kusum Rolls', "Kareem's",
#        'WOW! China', 'Golden Spoon', 'BarBQ', 'The Kebab Factory',
#        'Patisserie By Franziska', 'The Sixth Sense', 'Food King',
#        'Burgrill', 'Zainab Biryani', 'The Crepe Cafe'], dtype=object)

# %%
# Convert 'address' column to strings
df['address'] = df['address'].astype(str)

# %% [markdown]
# ### Adding another column called Location
# Adding another column called location which will contain the area not exact address of the restaurent

# %%
# Specify the chunk size
chunk_size = 100

# Create an empty 'Location' column
df['Location'] = ''

# Loop through chunks
for i in range(0, len(df['address']), chunk_size):
    chunk_addresses = df['address'].iloc[i:i + chunk_size]
    
    # Apply the extract_location function to the chunk and assign values to the 'Location' column
    df.loc[i:i + chunk_size - 1, 'Location'] = chunk_addresses.apply(extract_location)

# %%
# Visualize data
starting_index = 1000
df[starting_index:starting_index+5]
# Out:
#                                        name  voteCount rating  \
# 1000  The Anchorage Bar - The Floatel Hotel   53 votes    3.3
# 1001                        All Day Dinning  Cuisines:    NEW
# 1002                               Cakerica   12 votes    3.3
# 1003               Mughal Garden Restaurant  204 votes    3.8
# 1004                     The Bengal Ghorana  Cuisines:      -
#
#                                                 address  \
# 1000  9/10, Floatel, Kolkata Jetty, Strand Road, Dal...
# 1001          20B, Paddapukur Road, Bhawanipur, Kolkata
# 1002  37A, Justice Chandra Madhab Road, Bhawanipur, ...
# 1003  10, Kiran Shankar Roy Road, Near Millenium Par...
# 1004  1/3A, Rammoy Road, Near Health Point Nursing H...
#
#                               cusine    cost                   timing  \
# 1000  North Indian, Mughlai, Chinese  ₹2,000     1pm – 11pm (Mon-Sun)
# 1001  North Indian, Mughlai, Chinese    ₹900  8:30am – 11pm (Mon-Sun)
# 1002                    South Indian    ₹100      9am – 9pm (Mon-Sun)
# 1003                    South Indian    ₹400    11am – 11pm (Mon-Sun)
# 1004                  Rolls, Chinese  ₹2,000       24 Hours (Mon-Sun)
#
#                          Location
# 1000  Dalhousie BBD Bagh, Kolkata
# 1001          Bhawanipur, Kolkata
# 1002          Bhawanipur, Kolkata
# 1003  Dalhousie BBD Bagh, Kolkata
# 1004         Bhowanipore, Kolkata

# %% [markdown]
# ## Analyzing rating column and cleaning
# Analyzing the rating column and replacing the null entries

# %%
# Assuming df is your DataFrame and 'ratings' is the column containing ratings
unique_ratings = df['rating'].unique()

# Display the unique ratings
print("Unique Ratings:", unique_ratings)
# Out:
# Unique Ratings: ['4.2' '4.9' '4.4' '4.6' '4.1' '4.3' '4.0' '3.8' '3.6' 'NEW' nan '3.3'
#  '3.7' '3.9' '3.5' '3.2' '3.1' '3.0' '2.9' '-' '3.4' '2.3' '4.5' '2.8'
#  '4.7' '2.7' '2.6' '2.5' '2.1' '4.8' '2.4' '2.2' '1.9' '2.0']

# %% [markdown]
# Replace `NEW` and `-` ratings with `0` and `nan` with `-1`

# %%
# Assuming df is your DataFrame
# Replace 'NEW' with '0' and 'nan' with '-1' in the entire DataFrame
df.replace({'NEW': '0', np.nan: '-1', '-': '0'}, inplace=True)

# Now, the 'ratings' column should only contain numeric strings, and you can proceed with sorting
# Assuming 'ratings' is the column containing ratings
df['rating'] = df['rating'].astype(float)

# %%
# Sort the DataFrame based on the 'ratings' column
#df.sort_values(by='rating', inplace=True)

# Display the DataFrame
df
# Out:
#                       name    voteCount  rating  \
# 0                Peter Cat  12404 votes     4.2
# 1       Naturals Ice Cream   2498 votes     4.9
# 2               Carpe Diem   4083 votes     4.4
# 3          Barbeque Nation   5455 votes     4.6
# 4                   Flurys   4709 votes     4.2
# ...                    ...          ...     ...
# 7383             WOW! ARBA    Cuisines:     0.0
# 7384                Renu's     50 votes     2.8
# 7385        The Food Place    Cuisines:     0.0
# 7386  New Dalma Restaurant    Cuisines:     0.0
# 7387       Baanerjee Cabin    Cuisines:     0.0
#
#                                                 address  \
# 0           18A, Park Street, Park Street Area, Kolkata
# 1     77/1/A, Ground Floor, Near West Bengal Board, ...
# 2                        18M, Park Street Area, Kolkata
# 3     1st Floor, 24, Park Center Building, Park Stre...
# 4          15, Apeejay House, Park Street Area, Kolkata
# ...                                                 ...
# 7383                                      Delivery Only
# 7384  89/109, Vivekananda Road, Bangur Park, Hooghly...
# 7385  119, Ramkrishna Road, Radhashree, Landmark- Ai...
# 7386                                      Delivery Only
# 7387  89, Nripen Sarkar Road, Sahapukur, Sreedurga C...
#
#                                   cusine    cost  \
# 0              North Indian, Continental  ₹1,000
# 1              North Indian, Continental    ₹200
# 2                              Ice Cream  ₹1,000
# 3                              Ice Cream  ₹1,800
# 4     Chinese, North Indian, Continental    ₹400
# ...                                  ...     ...
# 7383                  Chinese, Fast Food    ₹150
# 7384                             Bengali    ₹350
# 7385                             Bengali    ₹150
# 7386                             Chinese    ₹250
# 7387                             Chinese    ₹200
#
#                                                timing  \
# 0                            11am – 11:20pm (Mon-Sun)
# 1                         11am – 12midnight (Mon-Sun)
# 2     12noon – 12midnight (Mon, Tue, Wed, Thu, Fri...
# 3         12noon – 3:30pm, 6:30pm – 10:45pm (Mon-Sun)
# 4                             7:30am – 11pm (Mon-Sun)
# ...                                               ...
# 7383                            11am – 11pm (Mon-Sun)
# 7384                            11am – 11pm (Mon-Sun)
# 7385                          8am – 11:45pm (Mon-Sun)
# 7386                       12noon – 10:30pm (Mon-Sun)
# 7387                            10am – 11pm (Mon-Sun)
#
#                        Location
# 0     Park Street Area, Kolkata
# 1     Park Street Area, Kolkata
# 2     Park Street Area, Kolkata
# 3     Park Street Area, Kolkata
# 4     Park Street Area, Kolkata
# ...                         ...
# 7383              Delivery Only
# 7384            Rishra, Kolkata
# 7385           Dum Dum, Kolkata
# 7386              Delivery Only
# 7387           Kalyani, Kolkata
#
# [7388 rows x 8 columns]

# %%
df[5000:5005]
# Out:
#                name  voteCount  rating  \
# 5000     Al Zaffran   88 votes     3.3
# 5001    The Kitchen  420 votes     4.0
# 5002        Foodizm  149 votes     3.5
# 5003  Mehek-E-Dawat  117 votes     3.1
# 5004       Hot Spot   38 votes     3.3
#
#                                                 address  \
# 5000  D/1/5, Santoshpur Station Road, Tara Tala, Kol...
# 5001                 P-188, Block-B, Lake Town, Kolkata
# 5002  262, B.T Road, Tobin Road Crossing, Baranagar,...
# 5003  59B, Becharam Chatterjee Road, State Bank Colo...
# 5004  Dum Dum Park Bazar, Near Mother Dairy, Dum Dum...
#
#                          cusine  cost                       timing  \
# 5000           Chinese, Mughlai  ₹500  11:30am – 10:30pm (Mon-Sun)
# 5001           Chinese, Mughlai  ₹900      12noon – 11pm (Mon-Sun)
# 5002  South Indian, Street Food  ₹500      12noon – 10pm (Mon-Sun)
# 5003  South Indian, Street Food  ₹400   12noon – 10:30pm (Mon-Sun)
# 5004                    Chinese  ₹300     12:30pm – 10pm (Mon-Sun)
#
#                 Location
# 5000  Tara Tala, Kolkata
# 5001  Lake Town, Kolkata
# 5002  Baranagar, Kolkata
# 5003     Behala, Kolkata
# 5004    Dum Dum, Kolkata

# %% [markdown]
# ## Analyzing unique locations

# %%
# Assuming df is your DataFrame and 'ratings' is the column containing ratings
unique_loc = df['Location'].unique()

# Display the unique ratings
print("Unique Locations:", unique_loc)
# Out:
# Unique Locations: ['Park Street Area, Kolkata' 'New Market Area, Kolkata'
#  'Russel Street Area, Kolkata' 'Ripon Street, Kolkata' 'Delivery Only'
#  ' Park Street Area, Kolkata' 'Near Park Circus Area, Kolkata'
#  'Mirza Ghalib Street Park Street Area, Kolkata'
#  'Park Circus Area, Kolkata' 'Wellesley, Kolkata'
#  'Camac Street Area, Kolkata' 'Elgin, Kolkata' 'Entally, Kolkata'
#  'Loudon Street Area, Kolkata' 'Theatre Road, Kolkata'
#  'Esplanade, Kolkata' 'Minto Park, Kolkata' 'Chowringhee, Kolkata'
#  'Taltala, Kolkata' '43B ripon street Kolkata'
#  'Beck Bagan Park Circus Area, Kolkata'
#  'IDBI Bank Building, New Market Area Kolkata' 'Near Elgin, Kolkata'
#  'Camac Street, Kolkata' '18, Hemanta Basu Sarani kolkata' 'nan'
#  'Nandalal Basu Sarani, Kolkata' 'Lord Sinha Road Elgin, Kolkata'
#  '\n Taltala, Kolkata' 'Circus Avenue Park Circus Area, Kolkata'
#  'Near Entally, Kolkata' 'Ballygunge, Kolkata' 'Bhawanipur, Kolkata'
#  'Paddapukur, Kolkata' 'Sealdah Area, Kolkata' 'Chandni Chowk, Kolkata'
#  'Bara Bazar, Kolkata' 'Kankurgachi, Kolkata'
#  'Dalhousie BBD Bagh, Kolkata' 'Bhowanipore, Kolkata' 'Bow Bazar, Kolkata'
#  'Harish Mukherjee Road Bhawanipur, Kolkata'
#  'Chandni Chowk Street, Kolkata' 'Hatibagan, Kolkata'
#  'Jodhpur Park, Kolkata' 'Bhawanipore, Kolkata' 'Tangra, Kolkata'
#  'Padupukur, Kolkata' 'Dalhouise BBD Bagh, Kolkata' 'New Town, Kolkata'
#  'Paddapukur, Kolkata\nNear hotel Aston.. \nopp to Laxmi narayan mandir.'
#  'College Street, Kolkata' 'Paddapukur, Hotel Mangalam'
#  '41A justice Chandra Madhab road Kolkata 700020' 'Salt Lake, Kolkata'
#  'Bow Bazaar, Kolkata' 'Falta, Kolkata' 'New Alipore, Kolkata'
#  'Gariahat, Kolkata' 'Kidderpore, Kolkata' 'Ruby Hospital Area, Kolkata'
#  'Picnic Garden, Kolkata' 'Shibpur, Howrah' 'Science City Area, Kolkata'
#  'Dhakuria, Kolkata' 'Tollygunge, Kolkata' 'Kalighat, Kolkata'
#  'Lake Gardens, Kolkata' 'Maniktala, Kolkata' 'Topsia, Kolkata'
#  'Golpark, Kolkata' 'Southern Avenue, Kolkata' 'Girish Park, Kolkata'
#  'Shyam Bazar, Kolkata' 'Beliaghata, Kolkata' 'Salt Lake City, Kolkata'
#  'Lake Town, Kolkata' 'Sector 1, Salt Lake'
#  'Prince Anwar Shah Road, Kolkata' 'Kadamtala, Howrah'
#  'Howrah Maidan Area, Howrah' 'Behala, Kolkata' 'Kasba, Kolkata'
#  'Hazra, Kolkata' 'Desapriya Park, Kolkata' 'Jadavpur, Kolkata'
#  'Tara Tala, Kolkata' 'Lake Market Area, Kolkata'
#  'Near Ballygunge, Kolkata' 'Santoshpur, Kolkata'
#  'Hindustan Park, Kolkata' 'Liluah, Howrah'
#  'Mechua Bazar, Bara Bazar,Kolkata' 'Shobha Bazar, Kolkata'
#  'Desapriya Park, kolkata'
#  'Kasba Industrial Estate,Behind Ruby Hospital Area, Kolkata'
#  'Salkia, Howrah' 'Howrah Station Area, Howrah' 'Kalikapur, Kolkata'
#  'Dobson Road, Howrah' 'Golf Green, Kolkata' 'Ultadanga, Kolkata'
#  'Andul Road, Howrah' 'Near Andul Road, Howrah' 'Kona Exp Way, Howrah'
#  'Near Girish Park, Kolkata' 'GT Road, Howrah' 'Alipore, Kolkata'
#  'Paikpara, Kolkata' 'Shalimar, Howrah' 'Near Shibpur, Howrah'
#  'Dobson Road, Kolkata' 'Ichapur, Howrah' 'Garia, Kolkata'
#  'Near Singh Builders, Picnic Garden. Kolkata' 'Hindustan Road, Kolkata'
#  'Near Howrah Station Area, Howrah' 'Parnasree Palli, Kolkata'
#  'Lake garden, Kolkata' 'Near Kidderpore, Kolkata'
#  '43/1/1 Bholanath Nandi Lane  Kona Expressway Crossing, Belepole'
#  'Baghajatin, Kolkata' 'Picnic\n\n Garden, Kolkata' 'Howrah, Kolkata'
#  'taltalla, Kolkata' '187, Sarat Bose Road'
#  'Howrah Chunabati More, Andul Road' 'Desapriya Park - West, Kolkata'
#  'Near Dhakuria, Kolkata' ' College Street, Kolkata'
#  '62/2 Andul Road, Howrah' 'Dum Dum, Kolkata' 'Scheme VIIM, Kankurgachi'
#  'Machuabazar, Kolkata' 'Chinar Park, Kolkata' 'Kankurgachi, Kolkata,'
#  'Navapalli,Kasba, Kolkata' 'Naktala, Kolkata' 'Sealdah, Kolkata'
#  'Despriya Park, Kolkata' 'Sector 4, Salt Lake'
#  '40a Ballygunge Place, Kolkata' 'Near Ruby Hospital Area, Kolkata'
#  '17/1 F, Alipore Road' 'Charaktola Behala, Kolkata' 'Pukur, Dhakuriya'
#  'Hati Bagan, Kolkata' 'Kona Exp Way, Kolkata' 'Sector 3, Salt Lake'
#  'Nutan Bazar, Kolkata' 'Chittaranjan Avenue, Kolkata'
#  'Manicktala, Kolkata' 'Belur, Howrah' 'Beleghata, Kolkata'
#  'Near Lake Town, Kolkata' 'Prince Anwer Shah Road, Kolkata'
#  'Kolkata, West Bengal' 'Jadavpur, Kolkata.' 'Fazir Bazar Shibpur, Howrah'
#  'Ambedkar Sarani, Tospia Road' 'Tollygunge, Kolkata,'
#  'Kalikapur Road, Kolkata' 'Bali, Howrah' 'Ballygunge, Koata'
#  ' Jodhpur Park, Kolkata' 'Near Picnic Garden, Kolkata'
#  'Swinehoe Lane Kasba, Kolkata' 'Phool Bagan, Kolkata Crossing Kolkata'
#  'Near Phulbagan Masjid, Kolkata' 'Chetla, Kolkata' 'Salt Lake, Kolkata.'
#  'Near Tollygunge, Kolkata' 'Lake View Road, Southern Avenue'
#  'NearTollygunge, Kolkata' 'Khardah, Kolkata'
#  'Andul Road, Howrah Near Chaitali More' 'Howrah Maiden Area, Howrah'
#  'Sinthi, Kolkata' 'Shantipally Kasba, Kolkata' 'Bally, Howrah'
#  'Ajoy Nagar, Kolkata' 'Near Howrah Maidan Area, Howrah'
#  'Bandhaghat, Salkia Kolkata' 'Ashoknagar, Tollygunge'
#  'Near Laxmi Narayan Mandir, Kasba' '375 Prince Anwar Shah Road, Kolkata'
#  '530A Jodhpur Park, Kolkata' 'Beliaghata Road, Kolkata'
#  'Near Kalikapur, Kolkata' ' Kankurgachi, Kolkata' 'Thakur Pukur, Kolkata'
#  'Deshapriya Park, Kolkata' 'Beliaghata Main Road Beliaghata, Kolkata'
#  'Das Naagar, Howrah' 'Near Salkia, Howrah' 'WARD NO 068, Kolkata'
#  'Sodepur, Kolkata' 'Nagerbazar, Kolkata' 'Sector 5, Salt Lake'
#  'Baguihati, Kolkata' 'Kestopur, Kolkata' 'Serampore, Kolkata'
#  'Kaikhali, Kolkata' 'Baranagar, Kolkata' 'Belghoria, Kolkata'
#  'Barasat, Kolkata' 'Bangur, Kolkata' 'Narendra Pur, Kolkata'
#  'Near Dum Dum, Kolkata' 'Kalyani, Kolkata' 'Barrackpore, Kolkata'
#  'Konnagar, Kolkata' 'Near Ajoy Nagar, Kolkata' 'Joka, Kolkata'
#  'Chandannagar, Kolkata' 'Uttarpara, Kolkata' 'Newtown, Kolkata'
#  'Rishra, Kolkata' 'Sonarpur, Kolkata'
#  'Barrackpore Station  Near 1 Number  Platform' 'Chinsura, Kolkata'
#  'Bhagjatin, Kolkata' 'Near Sodepur, Kolkata' 'Near Behala, Kolkata'
#  'Dum Dum, Kolkata-700028' 'Sector 2, Salt Lake'
#  'Near Nagerbazar, Kolkata' 'Near Barasat, Kolkata'
#  'A-1/2(S) Kalyani, Kolkata' 'Near Baguihati, Kolkata'
#  'Hindmotor, Kolkata' 'Near Narendra Pur, Kolkata' 'Newtown, Rajarhat'
#  'Beside Dunlop Bridge Mini Bus Stand, Baranagar'
#  'Near Belghoria, Kolkata' 'Near Naktala, Kolkata'
#  'Morepukur Rishra, Kolkata' 'Bireshpalli, Kolkata'
#  'Near New Town, Kolkata' 'Kamarhati Municipality Belghoria, Kolkata'
#  'Baguiati, Kolkata' 'Rajarhat, Kolkata' 'Near Chandannagar, Kolkata'
#  'Kalindi, Kolkata' 'Netaji Nagar, Tollygunge Kolkata'
#  'Near Kalyani, Kolkata' 'Unitech Gate 1 New Town, Kolkata'
#  'Near Uttarpara, Kolkata' 'Rishra, kolkata' 'DF Block New Town, Kolkata'
#  'Belur Math, Howrah' 'Avani Oxford, Kolkata' 'Kolkata, Kolkata'
#  'New Town, Kolkara' 'Chinar Park, opp Spencer and beside Arsanal.'
#  'Parganas Baranagar, Kolkata' ' Garia, Kolkata' 'Near Kaikhali, Kolkata'
#  'Near Rishra Municipal Office Rishra, Kolkata'
#  'North Twenty Four Parganas Dum Dum, Kolkata'
#  'Kudghat Bazar,Tollygunge, Kolkata'
#  'Near By Sabitri Apartment Baguihati, Kolkata' 'Narendrapur, Kolkata'
#  'Baguhati, Kolkata' 'NK Banerjee Road Rishra, Kolkata'
#  'Saheb Para Sodepur, Kolkata'
#  '28 Laldhiger dhar opp Jagadhatri Gaurage..Chandannaga 712136'
#  'Madhyamgram, Barasat' 'South Dum Dum, Kolkata' 'Behala, Kolkata,'
#  'HC Dutta Road, Sodepur Kolkata' 'Mandir Gate, Kolkata'
#  'N.S.C Bose Road,Tollygunge, Kolkata'
#  '126 H.L Sarkar Road Post Banshdroni Thana Garia, Kolkata'
#  'khardah, Kolkata' 'Hooghly, Kolkata' 'Ecospace New Town, Kolkata'
#  'Chinsurah, Kolkata' 'Nadia, Kolkata'
#  'Sunny Dew Apartment Garia, Kolkata' 'Newtown, kolkata'
#  'East Rajapur Santoshpur, Kolkata' 'Kanchrapara, West Bengal'
#  'Near Sinthi, Kolkata' 'Near Belur, Howrah' 'Near Keya More, Sodepur'
#  'Belur, Kolkata' 'Dakshin Behala Road, Behala' 'Birati, Kolkata'
#  'Baishnabghata Patuli Connector, Garia'
#  'Level Crossing Road,Baksara Bazar, Santragachi,Kolkata'
#  'Near Naktala Post Office, Kolkata'
#  'Thakdari Main Road, Newtown Action Area 1C' 'Khardah, kolkata'
#  'Action Area IIC, Newtown' 'Near Autostand Nagerbazar, Kolkata'
#  'Metiabruz, Kolkata' 'Kolkata Municipal Corporation, Kolkata'
#  'Belgharia, Kolkata' 'Dankuni, Hoogly'
#  'Bahattacharjee Serampore, Kolkata' 'Thakur Pukur Bazar, Kolkata'
#  'Madhyamgram, Kolkata' 'Kona Express Way, Howrah'
#  'Shop No. 32, A-2 Wholesale Market' 'A1/15 Kalyani, Kolkata'
#  'Rajarhat New Town, Kolkata' 'Near Garia, Kolkata'
#  'Near Barrackpore, Kolkata' 'NS Avenue Serampore, Kolkata'
#  'Near Post Office Ichapur, Howrah'
#  'Post Jadavpur University Baghajatin, Kolkata' 'Near Tara Tala, Kolkata'
#  'Paschim Barisha, Behala Kolkata' 'New Town, kolkata' 'Kolkata, 700144'
#  'Near Thakur Pukur, Kolkata' 'Konnagar, Bangalore' '14A Dum Dum, Kolkata'
#  'Near Jyoti Cinema, Chandannagar' 'Station Road Serampore, Kolkata'
#  'A Block Santoshpur, Kolkata' 'Near Swagatam Sangha Club, Kestopur'
#  'Dum Dum Road, Kolkata']

# %% [markdown]
# ### Splitting Location
# Column location needs to be split into two parts City and location
#
# I have created a helper function called `extract_part_of_loc` it can be used to extract parts of location

# %%
# Update the 'City' column with values
for i in range(len(df)):
    df.loc[i, 'City'] = extract_parts_of_loc(df.loc[i, 'address'], -1)

# %%
df.head()
# Out:
#                  name    voteCount  rating  \
# 0           Peter Cat  12404 votes     4.2
# 1  Naturals Ice Cream   2498 votes     4.9
# 2          Carpe Diem   4083 votes     4.4
# 3     Barbeque Nation   5455 votes     4.6
# 4              Flurys   4709 votes     4.2
#
#                                              address  \
# 0        18A, Park Street, Park Street Area, Kolkata
# 1  77/1/A, Ground Floor, Near West Bengal Board, ...
# 2                     18M, Park Street Area, Kolkata
# 3  1st Floor, 24, Park Center Building, Park Stre...
# 4       15, Apeejay House, Park Street Area, Kolkata
#
#                                cusine    cost  \
# 0           North Indian, Continental  ₹1,000
# 1           North Indian, Continental    ₹200
# 2                           Ice Cream  ₹1,000
# 3                           Ice Cream  ₹1,800
# 4  Chinese, North Indian, Continental    ₹400
#
#                                             timing                   Location  \
# 0                         11am – 11:20pm (Mon-Sun)  Park Street Area, Kolkata
# 1                      11am – 12midnight (Mon-Sun)  Park Street Area, Kolkata
# 2  12noon – 12midnight (Mon, Tue, Wed, Thu, Fri...  Park Street Area, Kolkata
# 3      12noon – 3:30pm, 6:30pm – 10:45pm (Mon-Sun)  Park Street Area, Kolkata
# 4                          7:30am – 11pm (Mon-Sun)  Park Street Area, Kolkata
#
#       City
# 0  Kolkata
# 1  Kolkata
# 2  Kolkata
# 3  Kolkata
# 4  Kolkata

# %% [markdown]
# Removing City names after commas from Location column

# %%
# Update the 'Location' column with values
for i in range(len(df)):
    df.loc[i, 'Location'] = extract_parts_of_loc(df.loc[i, 'address'], -2)

# %%
df[5000:5005]
# Out:
#                name  voteCount  rating  \
# 5000     Al Zaffran   88 votes     3.3
# 5001    The Kitchen  420 votes     4.0
# 5002        Foodizm  149 votes     3.5
# 5003  Mehek-E-Dawat  117 votes     3.1
# 5004       Hot Spot   38 votes     3.3
#
#                                                 address  \
# 5000  D/1/5, Santoshpur Station Road, Tara Tala, Kol...
# 5001                 P-188, Block-B, Lake Town, Kolkata
# 5002  262, B.T Road, Tobin Road Crossing, Baranagar,...
# 5003  59B, Becharam Chatterjee Road, State Bank Colo...
# 5004  Dum Dum Park Bazar, Near Mother Dairy, Dum Dum...
#
#                          cusine  cost                       timing   Location  \
# 5000           Chinese, Mughlai  ₹500  11:30am – 10:30pm (Mon-Sun)  Tara Tala
# 5001           Chinese, Mughlai  ₹900      12noon – 11pm (Mon-Sun)  Lake Town
# 5002  South Indian, Street Food  ₹500      12noon – 10pm (Mon-Sun)  Baranagar
# 5003  South Indian, Street Food  ₹400   12noon – 10:30pm (Mon-Sun)     Behala
# 5004                    Chinese  ₹300     12:30pm – 10pm (Mon-Sun)    Dum Dum
#
#          City
# 5000  Kolkata
# 5001  Kolkata
# 5002  Kolkata
# 5003  Kolkata
# 5004  Kolkata

# %% [markdown]
# ### VoteCount field
# Cleaning the unneccesary stuff present in voteCount column

# %%
# Remove 'votes' from the 'voteCount' column
df['voteCount'] = df['voteCount'].str.replace(' votes', '')

# Display the DataFrame
df[5000:5005]
# Out:
#                name voteCount  rating  \
# 5000     Al Zaffran        88     3.3
# 5001    The Kitchen       420     4.0
# 5002        Foodizm       149     3.5
# 5003  Mehek-E-Dawat       117     3.1
# 5004       Hot Spot        38     3.3
#
#                                                 address  \
# 5000  D/1/5, Santoshpur Station Road, Tara Tala, Kol...
# 5001                 P-188, Block-B, Lake Town, Kolkata
# 5002  262, B.T Road, Tobin Road Crossing, Baranagar,...
# 5003  59B, Becharam Chatterjee Road, State Bank Colo...
# 5004  Dum Dum Park Bazar, Near Mother Dairy, Dum Dum...
#
#                          cusine  cost                       timing   Location  \
# 5000           Chinese, Mughlai  ₹500  11:30am – 10:30pm (Mon-Sun)  Tara Tala
# 5001           Chinese, Mughlai  ₹900      12noon – 11pm (Mon-Sun)  Lake Town
# 5002  South Indian, Street Food  ₹500      12noon – 10pm (Mon-Sun)  Baranagar
# 5003  South Indian, Street Food  ₹400   12noon – 10:30pm (Mon-Sun)     Behala
# 5004                    Chinese  ₹300     12:30pm – 10pm (Mon-Sun)    Dum Dum
#
#          City
# 5000  Kolkata
# 5001  Kolkata
# 5002  Kolkata
# 5003  Kolkata
# 5004  Kolkata

# %%
# Remove '₹' from the 'cost' column
df['cost'] = df['cost'].str.replace('₹', '')

# Display the DataFrame
df[5000:5005]
# Out:
#                name voteCount  rating  \
# 5000     Al Zaffran        88     3.3
# 5001    The Kitchen       420     4.0
# 5002        Foodizm       149     3.5
# 5003  Mehek-E-Dawat       117     3.1
# 5004       Hot Spot        38     3.3
#
#                                                 address  \
# 5000  D/1/5, Santoshpur Station Road, Tara Tala, Kol...
# 5001                 P-188, Block-B, Lake Town, Kolkata
# 5002  262, B.T Road, Tobin Road Crossing, Baranagar,...
# 5003  59B, Becharam Chatterjee Road, State Bank Colo...
# 5004  Dum Dum Park Bazar, Near Mother Dairy, Dum Dum...
#
#                          cusine cost                       timing   Location  \
# 5000           Chinese, Mughlai  500  11:30am – 10:30pm (Mon-Sun)  Tara Tala
# 5001           Chinese, Mughlai  900      12noon – 11pm (Mon-Sun)  Lake Town
# 5002  South Indian, Street Food  500      12noon – 10pm (Mon-Sun)  Baranagar
# 5003  South Indian, Street Food  400   12noon – 10:30pm (Mon-Sun)     Behala
# 5004                    Chinese  300     12:30pm – 10pm (Mon-Sun)    Dum Dum
#
#          City
# 5000  Kolkata
# 5001  Kolkata
# 5002  Kolkata
# 5003  Kolkata
# 5004  Kolkata

# %%
# Assuming df is your processed DataFrame
df.to_csv('Zomato_processed_data.csv', index=False)
